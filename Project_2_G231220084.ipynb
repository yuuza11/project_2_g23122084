# %% [markdown]
# Insannul Imam Rohny Khoirri (G.231.22.0084)

# %% [markdown]
# Project 2

# %% [markdown]
# 1.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05e70445-0641-4aa3-8edc-b3bd735c2f7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05e70445-0641-4aa3-8edc-b3bd735c2f7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('hujan.csv')
df
# Out:
#     1981 - 1990  1991 - 2000  2001 - 2010
# 0           479          468          425
# 1           308          422          410
# 2           295          420          378
# 3           260          340          285
# 4           199          140          125
# 5           145          125          105
# 6            40           58           48
# 7            69           60            2
# 8           130           60           60
# 9           230          402          336
# 10          420          498          639
# 11          400          404          425

# %%
plt.figure(figsize=(10,5))

bulan = np.arange(1,13)

plt.bar(bulan, df['1981 - 1990'], width = 0.2, color='royalblue', label='1981 - 1990')
plt.bar(bulan + 0.2, df['1991 - 2000'], width = 0.2, color='firebrick', label='1991 - 2000')
plt.bar(bulan + 0.2 * 2, df['2001 - 2010'], width = 0.2, color='yellowgreen', label='2001 - 2010')

plt.xlabel('Bulan', weight='bold')
plt.ylabel('Curah Hujan (mm)', weight='bold')

plt.xticks(bulan + 0.2, bulan)

for i in range(20, 700, 20):
    plt.axhline(y=i, color='gray', linestyle='-', alpha=0.3)

plt.legend(loc="upper center", ncol=3, bbox_to_anchor=(0.5, 1.2))

plt.show()

# %% [markdown]
# 2.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f44fcaff-2a2e-4f17-8cb0-46b8637976eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f44fcaff-2a2e-4f17-8cb0-46b8637976eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('suhu.csv')
df
# Out:
#        Waktu  Asimilasi  Observasi  Non Asimilasi
# 0  00.00 UTC       23.0       24.0           23.4
# 1  03:00 UTC       25.2       25.0           25.4
# 2  06:00 UTC       25.5       23.8           25.1
# 3  09:00 UTC       24.8       23.9           25.5
# 4  12:00 UTC       22.5       24.0           24.9
# 5  15:00 UTC       22.2       24.2           25.0
# 6  18:00 UTC       23.0       24.0           24.5
# 7  21:00 UTC       22.0       22.8           24.0
# 8  00:00 UTC       25.9       23.0           26.0

# %%
data1 = df ['Asimilasi']
data2 = df ['Observasi']
data3 = df ['Non Asimilasi']
dates = df ['Waktu']

plt.figure(figsize=(10, 5))

plt.plot(dates, data1, marker='o', color='royalblue', label='Asimilasi')
plt.plot(dates, data3, marker='o', color='gold', label='Observasi')
plt.plot(dates, data2, marker='o', color='red', label='Non Asimilasi')

plt.xlabel('Waktu')
plt.ylabel('Celcius')
plt.title('Suhu Permukaan')
plt.legend(loc="lower right")

for d in [20,21, 22, 23, 24, 25, 26, 27]:
  plt.axhline(y=d, color='gray', linestyle='-', linewidth=0.3)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M UTC'))
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())


plt.show()
